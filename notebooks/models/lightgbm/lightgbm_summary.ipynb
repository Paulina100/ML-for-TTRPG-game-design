# %% [markdown]
# # Summary

# %%
import pandas as pd
import os
import pathlib


current_path = os.getcwd()
DATASETS_DIR = pathlib.Path(current_path)
DATASET_FILES = [
    "lightgbm_basic_results.csv",
    "lightgbm_expanded_results.csv",
    "lightgbm_full_results.csv",
]
DATASET_PATHS = [f"{DATASETS_DIR}/{file}" for file in DATASET_FILES]
results = [pd.read_csv(result, index_col=0) for result in DATASET_PATHS]
results = pd.concat(results, join="outer", axis=0).reset_index(drop=True)

# %%
results
# Out:
#        Split type Tuning type Set of features      RMSE       MAE
# 0   chronological     default           basic  0.758611  0.447891
# 1   chronological      Optuna           basic  0.754996  0.459143
# 2          random     default           basic  0.568104  0.368391
# 3          random      Optuna           basic  0.567588  0.364954
# 4   chronological     default        expanded  0.614277  0.376859
# 5   chronological      Optuna        expanded  0.590496  0.367707
# 6          random     default        expanded  0.416749  0.277924
# 7          random      Optuna        expanded  0.434797  0.280189
# 8   chronological     default            full  0.596209  0.355989
# 9   chronological      Optuna            full  0.555080  0.351413
# 10         random     default            full  0.379865  0.258236
# 11         random      Optuna            full  0.369164  0.240205

# %%
import sys

import os
import pathlib

sys.path.append("../../..")
from training.results import plot_summary, plot_one_type_split

# %% [markdown]
# ## MAE

# %% [markdown]
# ### All types of splits

# %%
plot_summary(results, "MAE", title="MAE for LightGBM", export=True)

# %% [markdown]
# Only tuned models

# %%
plot_summary(
    results[results["Tuning type"] != "default"], "MAE", title="MAE for tuned LightGBM"
)

# %% [markdown]
# ### Random split

# %%
plot_one_type_split(
    results, "random", "MAE", title="MAE for LightGBM with random split"
)

# %% [markdown]
# Only tuned models

# %%
plot_one_type_split(
    results[results["Tuning type"] != "default"],
    "random",
    "MAE",
    title="MAE for tuned LightGBM with random split",
)

# %% [markdown]
# ### Chronological split

# %%
plot_one_type_split(
    results, "chronological", "MAE", title="MAE for LightGBM with chronological split"
)

# %% [markdown]
# Only tuned models

# %%
plot_one_type_split(
    results[results["Tuning type"] != "default"],
    "chronological",
    "MAE",
    title="MAE for tuned LightGBM with chronological split",
)

# %% [markdown]
# ## RMSE

# %% [markdown]
# ### All tyes of splits

# %%
plot_summary(results, "RMSE", title="RMSE for LightGBM", export=True)

# %% [markdown]
# Only tuned models

# %%
plot_summary(
    results[results["Tuning type"] != "default"],
    "RMSE",
    title="RMSE for tuned LightGBM",
)

# %% [markdown]
# ### Random split

# %%
plot_one_type_split(
    results, "random", "RMSE", title="RMSE for LightGBM with random split"
)

# %% [markdown]
# Only tuned models

# %%
plot_one_type_split(
    results[results["Tuning type"] != "default"],
    "random",
    "RMSE",
    title="RMSE for tuned LightGBM with random split",
)

# %% [markdown]
# ### Chronological split

# %%
plot_one_type_split(
    results, "chronological", "RMSE", title="RMSE for LightGBM with chronological split"
)

# %% [markdown]
# Only tuned models

# %%
plot_one_type_split(
    results[results["Tuning type"] != "default"],
    "chronological",
    "RMSE",
    title="RMSE for tuned LightGBM with chronological split",
)
