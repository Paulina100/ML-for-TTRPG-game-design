# %% [markdown]
# # Summary

# %%
import pandas as pd
import os
import pathlib


current_path = os.getcwd()
DATASETS_DIR = pathlib.Path(current_path)
DATASET_FILES = [
    "lightgbm_basic_results.json",
    "lightgbm_second_results.json",
    "lightgbm_final_results.json",
]
DATASET_PATHS = [f"{DATASETS_DIR}/{file}" for file in DATASET_FILES]
results = [pd.read_json(result) for result in DATASET_PATHS]
results = pd.concat(results, join="outer", axis=0).reset_index(drop=True)

# %%
results
# Out:
#        Split type Tuning type  Number of characteristics       MSE      RMSE  \
# 0   chronological      normal                          8  0.447566  0.669004
# 1   chronological      Optuna                          8  0.447064  0.668629
# 2          random      normal                          8  0.243018  0.492968
# 3          random      Optuna                          8  0.277484  0.526768
# 4   chronological      normal                         13  0.260866  0.510751
# 5   chronological      Optuna                         13  0.193395  0.439767
# 6          random      normal                         13  0.148111  0.384853
# 7          random      Optuna                         13  0.114576  0.338490
# 8   chronological      normal                         50  0.913544  0.955795
# 9   chronological      Optuna                         50  0.769451  0.877184
# 10         random      normal                         50  0.137900  0.371349
# 11         random      Optuna                         50  0.097734  0.312624
#
#          MAE
# 0   0.467604
# 1   0.481825
# 2   0.340495
# 3   0.346474
# 4   0.357177
# 5   0.312398
# 6   0.267273
# 7   0.235578
# 8   0.459630
# 9   0.441060
# 10  0.246737
# 11  0.221938

# %%
import sys

import os
import pathlib

sys.path.append("../../..")
from training.results import plot_summary, plot_one_type_split

# %% [markdown]
# ## MAE

# %% [markdown]
# ### All types of splits

# %%
plot_summary(results, "MAE", title="MAE for LightGBM")

# %% [markdown]
# Only tuned models

# %%
plot_summary(
    results[results["Tuning type"] != "normal"], "MAE", title="MAE for tuned LightGBM"
)

# %% [markdown]
# ### Random split

# %%
plot_one_type_split(
    results, "random", "MAE", title="MAE for LightGBM with random split"
)

# %% [markdown]
# Only tuned models

# %%
plot_one_type_split(
    results[results["Tuning type"] != "normal"],
    "random",
    "MAE",
    title="MAE for tuned LightGBM with random split",
)

# %% [markdown]
# ### Chronological split

# %%
plot_one_type_split(
    results, "chronological", "MAE", title="MAE for LightGBM with chronological split"
)

# %% [markdown]
# Only tuned models

# %%
plot_one_type_split(
    results[results["Tuning type"] != "normal"],
    "chronological",
    "MAE",
    title="MAE for tuned LightGBM with chronological split",
)

# %% [markdown]
# ## RMSE

# %% [markdown]
# ### All tyes of splits

# %%
plot_summary(results, "RMSE", title="RMSE for LightGBM")

# %% [markdown]
# Only tuned models

# %%
plot_summary(
    results[results["Tuning type"] != "normal"], "RMSE", title="RMSE for tuned LightGBM"
)

# %% [markdown]
# ### Random split

# %%
plot_one_type_split(
    results, "random", "RMSE", title="RMSE for LightGBM with random split"
)

# %% [markdown]
# Only tuned models

# %%
plot_one_type_split(
    results[results["Tuning type"] != "normal"],
    "random",
    "RMSE",
    title="RMSE for tuned LightGBM with random split",
)

# %% [markdown]
# ### Chronological split

# %%
plot_one_type_split(
    results, "chronological", "RMSE", title="RMSE for LightGBM with chronological split"
)

# %% [markdown]
# Only tuned models

# %%
plot_one_type_split(
    results[results["Tuning type"] != "normal"],
    "chronological",
    "RMSE",
    title="RMSE for tuned LightGBM with chronological split",
)
