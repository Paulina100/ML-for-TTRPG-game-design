# %% [markdown]
# # Summary

# %%
import pandas as pd
import os
import pathlib


current_path = os.getcwd()
DATASETS_DIR = pathlib.Path(current_path)
DATASET_FILES = [
    "lightgbm_basic_results.json",
    "lightgbm_second_results.json",
    "lightgbm_final_results.json",
]
DATASET_PATHS = [f"{DATASETS_DIR}/{file}" for file in DATASET_FILES]
results = [pd.read_json(result) for result in DATASET_PATHS]
results = pd.concat(results, join="outer", axis=0).reset_index(drop=True)

# %%
results
# Out:
#        Split type Tuning type  Number of characteristics       MSE      RMSE  \
# 0   chronological      normal                          8  0.447566  0.669004
# 1   chronological      Optuna                          8  0.409605  0.640004
# 2          random      normal                          8  0.243018  0.492968
# 3          random      Optuna                          8  0.255307  0.505279
# 4   chronological      normal                         13  0.260889  0.510773
# 5   chronological      Optuna                         13  0.211634  0.460037
# 6          random      normal                         13  0.148111  0.384853
# 7          random      Optuna                         13  0.118242  0.343863
# 8   chronological      normal                         50  0.927292  0.962960
# 9   chronological      Optuna                         50  0.434040  0.658817
# 10         random      normal                         50  0.137900  0.371349
# 11         random      Optuna                         50  0.098534  0.313902
#
#          MAE
# 0   0.327607
# 1   0.450994
# 2   0.241464
# 3   0.322567
# 4   0.223589
# 5   0.334537
# 6   0.160495
# 7   0.236382
# 8   0.235042
# 9   0.371587
# 10  0.152952
# 11  0.222457

# %%
import sys

import os
import pathlib

sys.path.append("../../..")
from training.results import plot_summary, plot_one_type_split

# %% [markdown]
# ## MAE

# %% [markdown]
# ### All types of splits

# %%
plot_summary(results, "MAE")

# %% [markdown]
# Only tuned models

# %%
plot_summary(results[results["Tuning type"] != "normal"], "MAE")

# %% [markdown]
# ### Random split

# %%
plot_one_type_split(results, "random", "MAE")

# %% [markdown]
# Only tuned models

# %%
plot_one_type_split(results[results["Tuning type"] != "normal"], "random", "MAE")

# %% [markdown]
# ### Chronological split

# %%
plot_one_type_split(results, "chronological", "MAE")

# %% [markdown]
# Only tuned models

# %%
plot_one_type_split(results[results["Tuning type"] != "normal"], "chronological", "MAE")

# %% [markdown]
# ## RMSE

# %% [markdown]
# ### All tyes of splits

# %%
plot_summary(results, "RMSE")

# %% [markdown]
# Only tuned models

# %%
plot_summary(results[results["Tuning type"] != "normal"], "RMSE")

# %% [markdown]
# ### Random split

# %%
plot_one_type_split(results, "random", "RMSE")

# %% [markdown]
# Only tuned models

# %%
plot_one_type_split(results[results["Tuning type"] != "normal"], "random", "RMSE")

# %% [markdown]
# ### Chronological split

# %%
plot_one_type_split(results, "chronological", "RMSE")

# %% [markdown]
# Only tuned models

# %%
plot_one_type_split(
    results[results["Tuning type"] != "normal"], "chronological", "RMSE"
)
