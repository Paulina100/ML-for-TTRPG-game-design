# %% [markdown]
# # Summary

# %%
import pandas as pd
import os
import pathlib


current_path = os.getcwd()
DATASETS_DIR = pathlib.Path(current_path)
DATASET_FILES = [
    "linear_regression_basic_results.csv",
    "linear_regression_expanded_results.csv",
    "linear_regression_full_results.csv",
]
DATASET_PATHS = [f"{DATASETS_DIR}/{file}" for file in DATASET_FILES]
results = [pd.read_csv(result, index_col=0) for result in DATASET_PATHS]
results = pd.concat(results, join="outer", axis=0).reset_index(drop=True)

# %%
results
# Out:
#        Split type Tuning type Set of features      RMSE       MAE
# 0   chronological     default           basic  0.947648  0.673958
# 1          random     default           basic  0.824599  0.538489
# 2   chronological       Ridge           basic  0.956457  0.677980
# 3   chronological       Lasso           basic  0.953894  0.677665
# 4          random       Ridge           basic  0.825067  0.538193
# 5          random       Lasso           basic  0.823513  0.535896
# 6   chronological     default        expanded  0.594538  0.438196
# 7          random     default        expanded  0.570687  0.382039
# 8   chronological       Ridge        expanded  0.601106  0.441633
# 9   chronological       Lasso        expanded  0.595102  0.435859
# 10         random       Ridge        expanded  0.571694  0.380043
# 11         random       Lasso        expanded  0.570531  0.381640
# 12  chronological     default            full  0.742648  0.457334
# 13         random     default            full  0.573386  0.356771
# 14  chronological       Ridge            full  0.762007  0.475612
# 15  chronological       Lasso            full  0.698030  0.454756
# 16         random       Ridge            full  0.585067  0.354016
# 17         random       Lasso            full  0.561733  0.350091

# %%
import sys

import os
import pathlib

sys.path.append("../../..")
from training.results import plot_summary, plot_one_type_split

# %% [markdown]
# ## MAE

# %% [markdown]
# ### All types of splits

# %%
plot_summary(results, "MAE", title="MAE_for_Linear_Regression", export=True)

# %% [markdown]
# Only tuned models

# %%
plot_summary(
    results[results["Tuning type"] != "default"],
    "MAE",
    title="MAE for tuned Linear Regression",
)

# %% [markdown]
# ### Random split

# %%
plot_one_type_split(
    results, "random", "MAE", title="MAE for Linear Regression with random split"
)

# %% [markdown]
# Only tuned models

# %%
plot_one_type_split(
    results[results["Tuning type"] != "default"],
    "random",
    "MAE",
    title="MAE for tuned Linear Regression with random split",
)

# %% [markdown]
# ### Chronological split

# %%
plot_one_type_split(
    results,
    "chronological",
    "MAE",
    title="MAE for Linear Regression with chronological split",
)

# %% [markdown]
# Only tuned models

# %%
plot_one_type_split(
    results[results["Tuning type"] != "default"],
    "chronological",
    "MAE",
    title="MAE for tuned Linear Regression with chronological split",
)

# %% [markdown]
# ## RMSE
# ### All tyes of splits

# %%
plot_summary(results, "RMSE", title="RMSE for Linear Regression", export=True)

# %% [markdown]
# Only tuned ones

# %%
plot_summary(
    results[results["Tuning type"] != "default"],
    "RMSE",
    title="RMSE for tuned Linear Regression",
)

# %% [markdown]
# ### Random split

# %%
plot_one_type_split(
    results, "random", "RMSE", title="RMSE for Linear Regression with random split"
)

# %% [markdown]
# Only tuned models

# %%
plot_one_type_split(
    results[results["Tuning type"] != "default"],
    "random",
    "RMSE",
    title="RMSE for tuned Linear Regression with random split",
)

# %% [markdown]
# ### Chronological split

# %%
plot_one_type_split(
    results,
    "chronological",
    "RMSE",
    title="RMSE for Linear Regression with chronological split",
)

# %% [markdown]
# Only tuned models

# %%
plot_one_type_split(
    results[results["Tuning type"] != "default"],
    "chronological",
    "RMSE",
    title="RMSE for tuned Linear Regression with chronological split",
)
