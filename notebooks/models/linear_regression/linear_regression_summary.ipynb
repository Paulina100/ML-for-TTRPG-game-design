# %% [markdown]
# # Summary

# %%
import pandas as pd
import os
import pathlib


current_path = os.getcwd()
DATASETS_DIR = pathlib.Path(current_path)
DATASET_FILES = [
    "linear_regression_basic_results.csv",
    "linear_regression_expanded_results.csv",
    "linear_regression_full_results.csv",
]
DATASET_PATHS = [f"{DATASETS_DIR}/{file}" for file in DATASET_FILES]
results = [pd.read_csv(result, index_col=0) for result in DATASET_PATHS]
results = pd.concat(results, join="outer", axis=0).reset_index(drop=True)

# %%
results
# Out:
#        Split type Tuning type Set of features      RMSE       MAE
# 0   chronological     default           basic  0.988565  0.667662
# 1          random     default           basic  0.884995  0.590223
# 2   chronological       Ridge           basic  0.988885  0.669358
# 3   chronological       Lasso           basic  0.988471  0.664733
# 4          random       Ridge           basic  0.884996  0.590341
# 5          random       Lasso           basic  0.886048  0.590482
# 6   chronological     default        expanded  0.741046  0.477639
# 7          random     default        expanded  0.629343  0.417888
# 8   chronological       Ridge        expanded  0.716936  0.471467
# 9   chronological       Lasso        expanded  0.713125  0.474571
# 10         random       Ridge        expanded  0.631491  0.418370
# 11         random       Lasso        expanded  0.636724  0.421761
# 12  chronological     default            full  0.681864  0.453925
# ...

# %%
import sys

import os
import pathlib

sys.path.append("../../..")
from training.results import plot_summary, plot_one_type_split

# %% [markdown]
# ## MAE

# %% [markdown]
# ### All types of splits

# %%
plot_summary(results, "MAE", title="MAE_for_Linear_Regression", export=True)

# %% [markdown]
# Only tuned models

# %%
plot_summary(
    results[results["Tuning type"] != "default"],
    "MAE",
    title="MAE for tuned Linear Regression",
)

# %% [markdown]
# ### Random split

# %%
plot_one_type_split(
    results, "random", "MAE", title="MAE for Linear Regression with random split"
)

# %% [markdown]
# Only tuned models

# %%
plot_one_type_split(
    results[results["Tuning type"] != "default"],
    "random",
    "MAE",
    title="MAE for tuned Linear Regression with random split",
)

# %% [markdown]
# ### Chronological split

# %%
plot_one_type_split(
    results,
    "chronological",
    "MAE",
    title="MAE for Linear Regression with chronological split",
)

# %% [markdown]
# Only tuned models

# %%
plot_one_type_split(
    results[results["Tuning type"] != "default"],
    "chronological",
    "MAE",
    title="MAE for tuned Linear Regression with chronological split",
)

# %% [markdown]
# ## RMSE
# ### All tyes of splits

# %%
plot_summary(results, "RMSE", title="RMSE for Linear Regression", export=True)

# %% [markdown]
# Only tuned ones

# %%
plot_summary(
    results[results["Tuning type"] != "default"],
    "RMSE",
    title="RMSE for tuned Linear Regression",
)

# %% [markdown]
# ### Random split

# %%
plot_one_type_split(
    results, "random", "RMSE", title="RMSE for Linear Regression with random split"
)

# %% [markdown]
# Only tuned models

# %%
plot_one_type_split(
    results[results["Tuning type"] != "default"],
    "random",
    "RMSE",
    title="RMSE for tuned Linear Regression with random split",
)

# %% [markdown]
# ### Chronological split

# %%
plot_one_type_split(
    results,
    "chronological",
    "RMSE",
    title="RMSE for Linear Regression with chronological split",
)

# %% [markdown]
# Only tuned models

# %%
plot_one_type_split(
    results[results["Tuning type"] != "default"],
    "chronological",
    "RMSE",
    title="RMSE for tuned Linear Regression with chronological split",
)
