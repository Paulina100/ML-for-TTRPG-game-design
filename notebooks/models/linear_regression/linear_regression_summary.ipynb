# %% [markdown]
# # Summary

# %%
import pandas as pd
import os
import pathlib


current_path = os.getcwd()
DATASETS_DIR = pathlib.Path(current_path)
DATASET_FILES = [
    "linear_regression_basic_results.json",
    "linear_regression_second_results.json",
    "linear_regression_final_results.json",
]
DATASET_PATHS = [f"{DATASETS_DIR}/{file}" for file in DATASET_FILES]
results = [pd.read_json(result) for result in DATASET_PATHS]
results = pd.concat(results, join="outer", axis=0).reset_index(drop=True)

# %%
results
# Out:
#        Split type Tuning type  Number of characteristics       MSE      RMSE  \
# 0   chronological      normal                          8  0.898038  0.947648
# 1          random      normal                          8  0.679964  0.824599
# 2   chronological       Ridge                          8  0.914811  0.956457
# 3   chronological       Lasso                          8  0.909914  0.953894
# 4          random       Ridge                          8  0.680736  0.825067
# 5          random       Lasso                          8  0.678174  0.823513
# 6   chronological      normal                         13  0.353475  0.594538
# 7          random      normal                         13  0.325684  0.570687
# 8   chronological       Ridge                         13  0.361328  0.601106
# 9   chronological       Lasso                         13  0.354146  0.595102
# 10         random       Ridge                         13  0.326834  0.571694
# ...

# %%
import sys

import os
import pathlib

sys.path.append("../../..")
from training.results import plot_summary, plot_one_type_split

# %% [markdown]
# ## MAE

# %% [markdown]
# ### All types of splits

# %%
plot_summary(results, "MAE")

# %% [markdown]
# Only tuned models

# %%
plot_summary(results[results["Tuning type"] != "normal"], "MAE")

# %% [markdown]
# ### Random split

# %%
plot_one_type_split(results, "random", "MAE")

# %% [markdown]
# Only tuned models

# %%
plot_one_type_split(results[results["Tuning type"] != "normal"], "random", "MAE")

# %% [markdown]
# ### Chronological split

# %%
plot_one_type_split(results, "chronological", "MAE")

# %% [markdown]
# Only tuned models

# %%
plot_one_type_split(results[results["Tuning type"] != "normal"], "chronological", "MAE")

# %% [markdown]
# ## RMSE
# ### All tyes of splits

# %%
plot_summary(results, "RMSE")

# %% [markdown]
# Only tuned ones

# %%
plot_summary(results[results["Tuning type"] != "normal"], "RMSE")

# %% [markdown]
# ### Random split

# %%
plot_one_type_split(results, "random", "RMSE")

# %% [markdown]
# Only tuned models

# %%
plot_one_type_split(results[results["Tuning type"] != "normal"], "random", "RMSE")

# %% [markdown]
# ### Chronological split

# %%
plot_one_type_split(results, "chronological", "RMSE")

# %% [markdown]
# Only tuned models

# %%
plot_one_type_split(
    results[results["Tuning type"] != "normal"], "chronological", "RMSE"
)
