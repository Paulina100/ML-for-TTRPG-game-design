# %% [markdown]
# # Summary

# %%
import pandas as pd
import os
import pathlib


current_path = os.getcwd()
DATASETS_DIR = pathlib.Path(current_path)
DATASET_FILES = [
    "random_forest_basic_results.json",
    "random_forest_second_results.json",
    "random_forest_final_results.json",
]
DATASET_PATHS = [f"{DATASETS_DIR}/{file}" for file in DATASET_FILES]
results = [pd.read_json(result) for result in DATASET_PATHS]
results = pd.concat(results, join="outer", axis=0).reset_index(drop=True)

# %%
results
# Out:
#        Split type             Tuning type  Number of characteristics  \
# 0   chronological                  normal                          8
# 1   chronological      RandomizedSearchCV                          8
# 2   chronological  minimalise_overfitting                          8
# 3          random                  normal                          8
# 4          random      RandomizedSearchCV                          8
# 5          random  minimalise_overfitting                          8
# 6   chronological                  normal                         13
# 7   chronological      RandomizedSearchCV                         13
# 8   chronological  minimalise_overfitting                         13
# 9          random                  normal                         13
# 10         random      RandomizedSearchCV                         13
# 11         random  minimalise_overfitting                         13
# 12  chronological                  normal                         50
# 13  chronological      RandomizedSearchCV                         50
# 14  chronological  minimalise_overfitting                         50
# 15         random                  normal                         50
# 16         random      RandomizedSearchCV                         50
# 17         random  minimalise_overfitting                         50
#
#          MSE      RMSE       MAE
# 0   2.232047  1.494004  0.970906
# 1   0.452306  0.672537  0.428295
# 2   0.496157  0.704384  0.460843
# 3   1.671128  1.292721  0.919120
# 4   0.227646  0.477122  0.299321
# 5   0.239155  0.489034  0.307780
# 6   2.116940  1.454971  0.922727
# 7   0.243980  0.493943  0.331526
# 8   0.260289  0.510185  0.344990
# 9   1.568874  1.252547  0.896873
# 10  0.133763  0.365737  0.237703
# 11  0.134984  0.367402  0.239147
# 12  5.052516  2.247780  0.997719
# 13  0.693419  0.832718  0.438360
# 14  0.724663  0.851271  0.448506
# 15  1.511777  1.229543  0.919533
# 16  0.111453  0.333846  0.220771
# 17  0.109422  0.330790  0.221414

# %%
from training.results import plot_summary, plot_one_type_split

# %% [markdown]
# ## MAE

# %% [markdown]
# ### All types of splits

# %%
plot_summary(results, "MAE")

# %% [markdown]
# Only tuned models

# %%
plot_summary(results[results["Tuning type"] != "normal"], "MAE")

# %% [markdown]
# ### Random split

# %%
plot_one_type_split(results, "random", "MAE")

# %% [markdown]
# Only tuned models

# %%
plot_one_type_split(results[results["Tuning type"] != "normal"], "random", "MAE")

# %% [markdown]
# ### Chronological split

# %%
plot_one_type_split(results, "chronological", "MAE")

# %% [markdown]
# Only tuned models

# %%
plot_one_type_split(results[results["Tuning type"] != "normal"], "chronological", "MAE")

# %% [markdown]
# ## RMSE

# %% [markdown]
# ### All tyes of splits

# %%
plot_summary(results, "RMSE")

# %% [markdown]
# Only tuned models

# %%
plot_summary(results[results["Tuning type"] != "normal"], "RMSE")

# %% [markdown]
# ### Random split

# %%
plot_one_type_split(results, "random", "RMSE")

# %% [markdown]
# Only tuned models

# %%
plot_one_type_split(results[results["Tuning type"] != "normal"], "random", "RMSE")

# %% [markdown]
# ### Chronological split

# %%
plot_one_type_split(results, "chronological", "RMSE")

# %% [markdown]
# Only tuned models

# %%
plot_one_type_split(
    results[results["Tuning type"] != "normal"], "chronological", "RMSE"
)
