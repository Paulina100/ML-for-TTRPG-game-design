# %% [markdown]
# # Summary

# %%
import pandas as pd
import os
import pathlib


current_path = os.getcwd()
DATASETS_DIR = pathlib.Path(current_path)
DATASET_FILES = [
    "random_forest_basic_results.json",
    "random_forest_second_results.json",
    "random_forest_final_results.json",
]
DATASET_PATHS = [f"{DATASETS_DIR}/{file}" for file in DATASET_FILES]
results = [pd.read_json(result) for result in DATASET_PATHS]
results = pd.concat(results, join="outer", axis=0).reset_index(drop=True)

# %%
results
# Out:
#        Split type           Tuning type  Number of characteristics       MSE  \
# 0   chronological                normal                          8  2.232047
# 1   chronological    RandomizedSearchCV                          8  0.460968
# 2   chronological  minimise_overfitting                          8  0.463360
# 3          random                normal                          8  1.671128
# 4          random    RandomizedSearchCV                          8  0.230457
# 5          random  minimise_overfitting                          8  0.228662
# 6   chronological                normal                         13  2.115397
# 7   chronological    RandomizedSearchCV                         13  0.241540
# 8   chronological  minimise_overfitting                         13  0.261421
# 9          random                normal                         13  1.568874
# 10         random    RandomizedSearchCV                         13  0.133908
# 11         random  minimise_overfitting                         13  0.133507
# 12  chronological                normal                         50  5.052291
# 13  chronological    RandomizedSearchCV                         50  0.682409
# 14  chronological  minimise_overfitting                         50  1.010428
# 15         random                normal                         50  1.511852
# 16         random    RandomizedSearchCV                         50  0.117476
# 17         random  minimise_overfitting                         50  0.125831
#
#         RMSE       MAE
# 0   1.494004  1.191495
# 1   0.678946  0.431988
# 2   0.680706  0.439716
# 3   1.292721  1.049508
# 4   0.480059  0.303001
# 5   0.478187  0.302815
# 6   1.454440  1.159628
# 7   0.491467  0.331717
# 8   0.511294  0.345281
# 9   1.252547  1.016585
# 10  0.365935  0.238457
# 11  0.365386  0.237652
# 12  2.247730  1.454932
# 13  0.826080  0.437342
# 14  1.005200  0.477972
# 15  1.229574  0.996461
# 16  0.342748  0.225033
# 17  0.354727  0.227667

# %%
import sys

import os
import pathlib

sys.path.append("../../..")
from training.results import plot_summary, plot_one_type_split

# %% [markdown]
# ## MAE

# %% [markdown]
# ### All types of splits

# %%
plot_summary(results, "MAE", title="MAE for Random Forest")

# %% [markdown]
# Only tuned models

# %%
plot_summary(
    results[results["Tuning type"] != "normal"],
    "MAE",
    title="MAE for tuned Random Forest",
)

# %% [markdown]
# ### Random split

# %%
plot_one_type_split(
    results, "random", "MAE", title="MAE for Random Forest with random split"
)

# %% [markdown]
# Only tuned models

# %%
plot_one_type_split(
    results[results["Tuning type"] != "normal"],
    "random",
    "MAE",
    title="MAE for tuned Random Forest with random split",
)

# %% [markdown]
# ### Chronological split

# %%
plot_one_type_split(
    results,
    "chronological",
    "MAE",
    title="MAE for Random Forest with chronological split",
)

# %% [markdown]
# Only tuned models

# %%
plot_one_type_split(
    results[results["Tuning type"] != "normal"],
    "chronological",
    "MAE",
    title="MAE for tuned Random Forest with chronological split",
)

# %% [markdown]
# ## RMSE

# %% [markdown]
# ### All tyes of splits

# %%
plot_summary(results, "RMSE", title="RMSE for Random Forest")

# %% [markdown]
# Only tuned models

# %%
plot_summary(
    results[results["Tuning type"] != "normal"],
    "RMSE",
    title="RMSE for tuned Random Forest",
)

# %% [markdown]
# ### Random split

# %%
plot_one_type_split(
    results, "random", "RMSE", title="RMSE for Random Forest with random split"
)

# %% [markdown]
# Only tuned models

# %%
plot_one_type_split(
    results[results["Tuning type"] != "normal"],
    "random",
    "RMSE",
    title="RMSE for tuned Random Forest with random split",
)

# %% [markdown]
# ### Chronological split

# %%
plot_one_type_split(
    results,
    "chronological",
    "RMSE",
    title="RMSE for Random Forest with chronological split",
)

# %% [markdown]
# Only tuned models

# %%
plot_one_type_split(
    results[results["Tuning type"] != "normal"],
    "chronological",
    "RMSE",
    title="RMSE for tuned Random Forest with chronological split",
)
