# %% [markdown]
# # Summary

# %%
import pandas as pd
import os
import pathlib


current_path = os.getcwd()
DATASETS_DIR = pathlib.Path(current_path)
DATASET_FILES = [
    "random_forest_basic_results.json",
    "random_forest_expanded_results.json",
    "random_forest_full_results.json",
]
DATASET_PATHS = [f"{DATASETS_DIR}/{file}" for file in DATASET_FILES]
results = [pd.read_json(result) for result in DATASET_PATHS]
results = pd.concat(results, join="outer", axis=0).reset_index(drop=True)

# %%
results
# Out:
#        Split type           Tuning type Set of features      RMSE       MAE
# 0   chronological               default           basic  1.494004  1.191495
# 1   chronological    RandomizedSearchCV           basic  0.679806  0.434595
# 2   chronological  minimise_overfitting           basic  0.686577  0.441139
# 3          random               default           basic  1.292721  1.049508
# 4          random    RandomizedSearchCV           basic  0.476736  0.299520
# 5          random  minimise_overfitting           basic  0.478757  0.300199
# 6   chronological               default        expanded  1.454971  1.160199
# 7   chronological    RandomizedSearchCV        expanded  0.493893  0.332075
# 8   chronological  minimise_overfitting        expanded  0.515195  0.344940
# 9          random               default        expanded  1.252547  1.016585
# 10         random    RandomizedSearchCV        expanded  0.366577  0.239255
# 11         random  minimise_overfitting        expanded  0.365327  0.239784
# 12  chronological               default            full  2.247783  1.454965
# 13  chronological    RandomizedSearchCV            full  0.811003  0.434621
# 14  chronological  minimise_overfitting            full  1.009472  0.480486
# 15         random               default            full  1.229635  0.996461
# 16         random    RandomizedSearchCV            full  0.328909  0.219232
# 17         random  minimise_overfitting            full  0.352734  0.226024

# %%
import sys

import os
import pathlib

sys.path.append("../../..")
from training.results import plot_summary, plot_one_type_split

# %% [markdown]
# ## MAE

# %% [markdown]
# ### All types of splits

# %%
plot_summary(results, "MAE", title="MAE for Random Forest")

# %% [markdown]
# Only tuned models

# %%
plot_summary(
    results[results["Tuning type"] != "default"],
    "MAE",
    title="MAE for tuned Random Forest",
)

# %% [markdown]
# ### Random split

# %%
plot_one_type_split(
    results, "random", "MAE", title="MAE for Random Forest with random split"
)

# %% [markdown]
# Only tuned models

# %%
plot_one_type_split(
    results[results["Tuning type"] != "default"],
    "random",
    "MAE",
    title="MAE for tuned Random Forest with random split",
)

# %% [markdown]
# ### Chronological split

# %%
plot_one_type_split(
    results,
    "chronological",
    "MAE",
    title="MAE for Random Forest with chronological split",
)

# %% [markdown]
# Only tuned models

# %%
plot_one_type_split(
    results[results["Tuning type"] != "default"],
    "chronological",
    "MAE",
    title="MAE for tuned Random Forest with chronological split",
)

# %% [markdown]
# ## RMSE

# %% [markdown]
# ### All tyes of splits

# %%
plot_summary(results, "RMSE", title="RMSE for Random Forest")

# %% [markdown]
# Only tuned models

# %%
plot_summary(
    results[results["Tuning type"] != "default"],
    "RMSE",
    title="RMSE for tuned Random Forest",
)

# %% [markdown]
# ### Random split

# %%
plot_one_type_split(
    results, "random", "RMSE", title="RMSE for Random Forest with random split"
)

# %% [markdown]
# Only tuned models

# %%
plot_one_type_split(
    results[results["Tuning type"] != "default"],
    "random",
    "RMSE",
    title="RMSE for tuned Random Forest with random split",
)

# %% [markdown]
# ### Chronological split

# %%
plot_one_type_split(
    results,
    "chronological",
    "RMSE",
    title="RMSE for Random Forest with chronological split",
)

# %% [markdown]
# Only tuned models

# %%
plot_one_type_split(
    results[results["Tuning type"] != "default"],
    "chronological",
    "RMSE",
    title="RMSE for tuned Random Forest with chronological split",
)
