# %% [markdown]
# # Summary

# %%
import pandas as pd
import os
import pathlib


current_path = os.getcwd()
DATASETS_DIR = pathlib.Path(current_path)
DATASET_FILES = [
    "random_forest_basic_results.csv",
    "random_forest_expanded_results.csv",
    "random_forest_full_results.csv",
]
DATASET_PATHS = [f"{DATASETS_DIR}/{file}" for file in DATASET_FILES]
results = [pd.read_csv(result, index_col=0) for result in DATASET_PATHS]
results = pd.concat(results, join="outer", axis=0).reset_index(drop=True)

# %%
results
# Out:
#        Split type           Tuning type Set of features      RMSE       MAE
# 0   chronological               default           basic  1.494004  1.191495
# 1   chronological    RandomizedSearchCV           basic  0.675481  0.430810
# 2   chronological  minimise_overfitting           basic  0.676719  0.434398
# 3          random               default           basic  1.292721  1.049508
# 4          random    RandomizedSearchCV           basic  0.483886  0.302737
# 5          random  minimise_overfitting           basic  0.478710  0.300321
# 6   chronological               default        expanded  1.454971  1.160199
# 7   chronological    RandomizedSearchCV        expanded  0.495759  0.334286
# 8   chronological  minimise_overfitting        expanded  0.514428  0.345717
# 9          random               default        expanded  1.252547  1.016585
# 10         random    RandomizedSearchCV        expanded  0.355139  0.234711
# ...

# %%
import sys

import os
import pathlib

sys.path.append("../../..")
from training.results import plot_summary, plot_one_type_split

# %% [markdown]
# ## MAE

# %% [markdown]
# ### All types of splits

# %%
plot_summary(results, "MAE", title="MAE for Random Forest", export=True)

# %% [markdown]
# Only tuned models

# %%
plot_summary(
    results[results["Tuning type"] != "default"],
    "MAE",
    title="MAE for tuned Random Forest",
)

# %% [markdown]
# ### Random split

# %%
plot_one_type_split(
    results, "random", "MAE", title="MAE for Random Forest with random split"
)

# %% [markdown]
# Only tuned models

# %%
plot_one_type_split(
    results[results["Tuning type"] != "default"],
    "random",
    "MAE",
    title="MAE for tuned Random Forest with random split",
)

# %% [markdown]
# ### Chronological split

# %%
plot_one_type_split(
    results,
    "chronological",
    "MAE",
    title="MAE for Random Forest with chronological split",
)

# %% [markdown]
# Only tuned models

# %%
plot_one_type_split(
    results[results["Tuning type"] != "default"],
    "chronological",
    "MAE",
    title="MAE for tuned Random Forest with chronological split",
)

# %% [markdown]
# ## RMSE

# %% [markdown]
# ### All tyes of splits

# %%
plot_summary(results, "RMSE", title="RMSE for Random Forest", export=True)

# %% [markdown]
# Only tuned models

# %%
plot_summary(
    results[results["Tuning type"] != "default"],
    "RMSE",
    title="RMSE for tuned Random Forest",
)

# %% [markdown]
# ### Random split

# %%
plot_one_type_split(
    results, "random", "RMSE", title="RMSE for Random Forest with random split"
)

# %% [markdown]
# Only tuned models

# %%
plot_one_type_split(
    results[results["Tuning type"] != "default"],
    "random",
    "RMSE",
    title="RMSE for tuned Random Forest with random split",
)

# %% [markdown]
# ### Chronological split

# %%
plot_one_type_split(
    results,
    "chronological",
    "RMSE",
    title="RMSE for Random Forest with chronological split",
)

# %% [markdown]
# Only tuned models

# %%
plot_one_type_split(
    results[results["Tuning type"] != "default"],
    "chronological",
    "RMSE",
    title="RMSE for tuned Random Forest with chronological split",
)
