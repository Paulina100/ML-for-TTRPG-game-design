# %% [markdown]
# # Summary

# %%
import pandas as pd
import os
import pathlib


current_path = os.getcwd()
DATASETS_DIR = pathlib.Path(current_path)
DATASET_FILES = [
    "random_forest_basic_results.json",
    "random_forest_second_results.json",
    "random_forest_final_results.json",
]
DATASET_PATHS = [f"{DATASETS_DIR}/{file}" for file in DATASET_FILES]
results = [pd.read_json(result) for result in DATASET_PATHS]
results = pd.concat(results, join="outer", axis=0).reset_index(drop=True)

# %%
results
# Out:
#        Split type           Tuning type  Number of characteristics       MSE  \
# 0   chronological                normal                          8  2.232047
# 1   chronological    RandomizedSearchCV                          8  0.455928
# 2   chronological  minimise_overfitting                          8  0.462115
# 3          random                normal                          8  1.671128
# 4          random    RandomizedSearchCV                          8  0.225162
# 5          random  minimise_overfitting                          8  0.227051
# 6   chronological                normal                         13  2.115397
# 7   chronological    RandomizedSearchCV                         13  0.252373
# 8   chronological  minimise_overfitting                         13  0.264290
# 9          random                normal                         13  1.568874
# 10         random    RandomizedSearchCV                         13  0.133967
# 11         random  minimise_overfitting                         13  0.134684
# 12  chronological                normal                         50  5.052798
# 13  chronological    RandomizedSearchCV                         50  0.689714
# 14  chronological  minimise_overfitting                         50  0.999689
# 15         random                normal                         50  1.511662
# 16         random    RandomizedSearchCV                         50  0.123290
# 17         random  minimise_overfitting                         50  0.125549
#
#         RMSE       MAE
# 0   1.494004  1.191495
# 1   0.675224  0.432621
# 2   0.679790  0.439203
# 3   1.292721  1.049508
# 4   0.474513  0.301702
# 5   0.476499  0.300386
# 6   1.454440  1.159628
# 7   0.502367  0.331352
# 8   0.514091  0.344461
# 9   1.252547  1.016585
# 10  0.366015  0.239863
# 11  0.366993  0.240132
# 12  2.247843  1.454898
# 13  0.830490  0.438695
# 14  0.999845  0.481023
# 15  1.229497  0.996461
# 16  0.351126  0.229474
# 17  0.354329  0.228372

# %%
import sys

import os
import pathlib

sys.path.append("../../..")
from training.results import plot_summary, plot_one_type_split

# %% [markdown]
# ## MAE

# %% [markdown]
# ### All types of splits

# %%
plot_summary(results, "MAE")

# %% [markdown]
# Only tuned models

# %%
plot_summary(results[results["Tuning type"] != "normal"], "MAE")

# %% [markdown]
# ### Random split

# %%
plot_one_type_split(results, "random", "MAE")

# %% [markdown]
# Only tuned models

# %%
plot_one_type_split(results[results["Tuning type"] != "normal"], "random", "MAE")

# %% [markdown]
# ### Chronological split

# %%
plot_one_type_split(results, "chronological", "MAE")

# %% [markdown]
# Only tuned models

# %%
plot_one_type_split(results[results["Tuning type"] != "normal"], "chronological", "MAE")

# %% [markdown]
# ## RMSE

# %% [markdown]
# ### All tyes of splits

# %%
plot_summary(results, "RMSE")

# %% [markdown]
# Only tuned models

# %%
plot_summary(results[results["Tuning type"] != "normal"], "RMSE")

# %% [markdown]
# ### Random split

# %%
plot_one_type_split(results, "random", "RMSE")

# %% [markdown]
# Only tuned models

# %%
plot_one_type_split(results[results["Tuning type"] != "normal"], "random", "RMSE")

# %% [markdown]
# ### Chronological split

# %%
plot_one_type_split(results, "chronological", "RMSE")

# %% [markdown]
# Only tuned models

# %%
plot_one_type_split(
    results[results["Tuning type"] != "normal"], "chronological", "RMSE"
)
