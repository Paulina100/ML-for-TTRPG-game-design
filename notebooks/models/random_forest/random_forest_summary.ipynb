# %% [markdown]
# # Summary

# %%
import pandas as pd
import os
import pathlib


current_path = os.getcwd()
DATASETS_DIR = pathlib.Path(current_path)
DATASET_FILES = [
    "random_forest_basic_results.json",
    "random_forest_expanded_results.json",
    "random_forest_full_results.json",
]
DATASET_PATHS = [f"{DATASETS_DIR}/{file}" for file in DATASET_FILES]
results = [pd.read_json(result) for result in DATASET_PATHS]
results = pd.concat(results, join="outer", axis=0).reset_index(drop=True)

# %%
results
# Out:
#        Split type           Tuning type Set of features       MSE      RMSE  \
# 0   chronological               default           basic  2.232047  1.494004
# 1   chronological    RandomizedSearchCV           basic  0.458934  0.677447
# 2   chronological  minimise_overfitting           basic  0.461174  0.679098
# 3          random               default           basic  1.671128  1.292721
# 4          random    RandomizedSearchCV           basic  0.227376  0.476840
# 5          random  minimise_overfitting           basic  0.226532  0.475954
# 6   chronological               default        expanded  2.115397  1.454440
# 7   chronological    RandomizedSearchCV        expanded  0.247925  0.497921
# 8   chronological  minimise_overfitting        expanded  0.258628  0.508555
# 9          random               default        expanded  1.568874  1.252547
# 10         random    RandomizedSearchCV        expanded  0.127313  0.356809
# 11         random  minimise_overfitting        expanded  0.133225  0.365000
# 12  chronological               default            full  5.052206  2.247711
# 13  chronological    RandomizedSearchCV            full  0.684766  0.827506
# 14  chronological  minimise_overfitting            full  0.990474  0.995226
# 15         random               default            full  1.511662  1.229497
# 16         random    RandomizedSearchCV            full  0.110824  0.332902
# 17         random  minimise_overfitting            full  0.128472  0.358430
#
#          MAE
# 0   1.191495
# 1   0.435324
# 2   0.441274
# 3   1.049508
# 4   0.301682
# 5   0.299932
# 6   1.159628
# 7   0.331065
# 8   0.344412
# 9   1.016585
# 10  0.239273
# 11  0.236840
# 12  1.454863
# 13  0.438813
# 14  0.477657
# 15  0.996461
# 16  0.219830
# 17  0.230062

# %%
import sys

import os
import pathlib

sys.path.append("../../..")
from training.results import plot_summary, plot_one_type_split

# %% [markdown]
# ## MAE

# %% [markdown]
# ### All types of splits

# %%
plot_summary(results, "MAE", title="MAE for Random Forest")

# %% [markdown]
# Only tuned models

# %%
plot_summary(
    results[results["Tuning type"] != "default"],
    "MAE",
    title="MAE for tuned Random Forest",
)

# %% [markdown]
# ### Random split

# %%
plot_one_type_split(
    results, "random", "MAE", title="MAE for Random Forest with random split"
)

# %% [markdown]
# Only tuned models

# %%
plot_one_type_split(
    results[results["Tuning type"] != "default"],
    "random",
    "MAE",
    title="MAE for tuned Random Forest with random split",
)

# %% [markdown]
# ### Chronological split

# %%
plot_one_type_split(
    results,
    "chronological",
    "MAE",
    title="MAE for Random Forest with chronological split",
)

# %% [markdown]
# Only tuned models

# %%
plot_one_type_split(
    results[results["Tuning type"] != "default"],
    "chronological",
    "MAE",
    title="MAE for tuned Random Forest with chronological split",
)

# %% [markdown]
# ## RMSE

# %% [markdown]
# ### All tyes of splits

# %%
plot_summary(results, "RMSE", title="RMSE for Random Forest")

# %% [markdown]
# Only tuned models

# %%
plot_summary(
    results[results["Tuning type"] != "default"],
    "RMSE",
    title="RMSE for tuned Random Forest",
)

# %% [markdown]
# ### Random split

# %%
plot_one_type_split(
    results, "random", "RMSE", title="RMSE for Random Forest with random split"
)

# %% [markdown]
# Only tuned models

# %%
plot_one_type_split(
    results[results["Tuning type"] != "default"],
    "random",
    "RMSE",
    title="RMSE for tuned Random Forest with random split",
)

# %% [markdown]
# ### Chronological split

# %%
plot_one_type_split(
    results,
    "chronological",
    "RMSE",
    title="RMSE for Random Forest with chronological split",
)

# %% [markdown]
# Only tuned models

# %%
plot_one_type_split(
    results[results["Tuning type"] != "default"],
    "chronological",
    "RMSE",
    title="RMSE for tuned Random Forest with chronological split",
)
