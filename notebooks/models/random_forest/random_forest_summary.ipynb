# %% [markdown]
# # Summary

# %%
import pandas as pd
import os
import pathlib


current_path = os.getcwd()
DATASETS_DIR = pathlib.Path(current_path)
DATASET_FILES = [
    "random_forest_basic_results.csv",
    "random_forest_expanded_results.csv",
    "random_forest_full_results.csv",
]
DATASET_PATHS = [f"{DATASETS_DIR}/{file}" for file in DATASET_FILES]
results = [pd.read_csv(result, index_col=0) for result in DATASET_PATHS]
results = pd.concat(results, join="outer", axis=0).reset_index(drop=True)

# %%
results
# Out:
#        Split type           Tuning type Set of features      RMSE       MAE
# 0   chronological               default           basic  1.624714  1.269617
# 1   chronological    RandomizedSearchCV           basic  0.742088  0.421242
# 2   chronological  minimize_overfitting           basic  0.754572  0.447525
# 3          random               default           basic  1.547770  1.244916
# 4          random    RandomizedSearchCV           basic  0.532375  0.317936
# 5          random  minimize_overfitting           basic  0.532991  0.319828
# 6   chronological               default        expanded  1.595830  1.254124
# 7   chronological    RandomizedSearchCV        expanded  0.593897  0.356733
# 8   chronological  minimize_overfitting        expanded  0.622743  0.382843
# 9          random               default        expanded  1.471212  1.177367
# 10         random    RandomizedSearchCV        expanded  0.403355  0.249259
# 11         random  minimize_overfitting        expanded  0.411986  0.251939
# 12  chronological               default            full  1.594948  1.253155
# 13  chronological    RandomizedSearchCV            full  0.573357  0.335350
# 14  chronological  minimize_overfitting            full  0.603324  0.361635
# 15         random               default            full  1.466061  1.173841
# 16         random    RandomizedSearchCV            full  0.362005  0.226245
# 17         random  minimize_overfitting            full  0.380030  0.233023

# %%
import sys

import os
import pathlib

sys.path.append("../../..")
from training.results import plot_summary, plot_one_type_split

# %% [markdown]
# ## MAE

# %% [markdown]
# ### All types of splits

# %%
plot_summary(results, "MAE", title="MAE for Random Forest", export=True)

# %% [markdown]
# Only tuned models

# %%
plot_summary(
    results[results["Tuning type"] != "default"],
    "MAE",
    title="MAE for tuned Random Forest",
)

# %% [markdown]
# ### Random split

# %%
plot_one_type_split(
    results, "random", "MAE", title="MAE for Random Forest with random split"
)

# %% [markdown]
# Only tuned models

# %%
plot_one_type_split(
    results[results["Tuning type"] != "default"],
    "random",
    "MAE",
    title="MAE for tuned Random Forest with random split",
)

# %% [markdown]
# ### Chronological split

# %%
plot_one_type_split(
    results,
    "chronological",
    "MAE",
    title="MAE for Random Forest with chronological split",
)

# %% [markdown]
# Only tuned models

# %%
plot_one_type_split(
    results[results["Tuning type"] != "default"],
    "chronological",
    "MAE",
    title="MAE for tuned Random Forest with chronological split",
)

# %% [markdown]
# ## RMSE

# %% [markdown]
# ### All tyes of splits

# %%
plot_summary(results, "RMSE", title="RMSE for Random Forest", export=True)

# %% [markdown]
# Only tuned models

# %%
plot_summary(
    results[results["Tuning type"] != "default"],
    "RMSE",
    title="RMSE for tuned Random Forest",
)

# %% [markdown]
# ### Random split

# %%
plot_one_type_split(
    results, "random", "RMSE", title="RMSE for Random Forest with random split"
)

# %% [markdown]
# Only tuned models

# %%
plot_one_type_split(
    results[results["Tuning type"] != "default"],
    "random",
    "RMSE",
    title="RMSE for tuned Random Forest with random split",
)

# %% [markdown]
# ### Chronological split

# %%
plot_one_type_split(
    results,
    "chronological",
    "RMSE",
    title="RMSE for Random Forest with chronological split",
)

# %% [markdown]
# Only tuned models

# %%
plot_one_type_split(
    results[results["Tuning type"] != "default"],
    "chronological",
    "RMSE",
    title="RMSE for tuned Random Forest with chronological split",
)
