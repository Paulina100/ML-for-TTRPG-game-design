# %% [markdown]
# # Summary

# %%
import pandas as pd
import os
import pathlib


current_path = os.getcwd()
DATASETS_DIR = pathlib.Path(current_path)
DATASET_FILES = [
    "random_forest_basic_results.json",
    "random_forest_second_results.json",
    "random_forest_final_results.json",
]
DATASET_PATHS = [f"{DATASETS_DIR}/{file}" for file in DATASET_FILES]
results = [pd.read_json(result) for result in DATASET_PATHS]
results = pd.concat(results, join="outer", axis=0).reset_index(drop=True)

# %%
results
# Out:
#        Split type           Tuning type Set of features       MSE      RMSE  \
# 0   chronological               default           basic  2.232047  1.494004
# 1   chronological    RandomizedSearchCV           basic  0.458508  0.677132
# 2   chronological  minimise_overfitting           basic  0.470219  0.685725
# 3          random               default           basic  1.671128  1.292721
# 4          random    RandomizedSearchCV           basic  0.227902  0.477391
# 5          random  minimise_overfitting           basic  0.231119  0.480748
# 6   chronological               default        expanded  2.115397  1.454440
# 7   chronological    RandomizedSearchCV        expanded  0.243179  0.493131
# 8   chronological  minimise_overfitting        expanded  0.259722  0.509629
# 9          random               default        expanded  1.568874  1.252547
# 10         random    RandomizedSearchCV        expanded  0.128890  0.359013
# 11         random  minimise_overfitting        expanded  0.135356  0.367908
# 12  chronological               default            full  5.052291  2.247730
# 13  chronological    RandomizedSearchCV            full  1.002046  1.001023
# 14  chronological  minimise_overfitting            full  1.002654  1.001326
# 15         random               default            full  1.511777  1.229543
# 16         random    RandomizedSearchCV            full  0.111088  0.333298
# 17         random  minimise_overfitting            full  0.126756  0.356029
#
#          MAE
# 0   1.191495
# 1   0.435221
# 2   0.442959
# 3   1.049508
# 4   0.305381
# 5   0.303120
# 6   1.159628
# 7   0.332237
# 8   0.343492
# 9   1.016585
# 10  0.236684
# 11  0.238030
# 12  1.454932
# 13  0.474192
# 14  0.478319
# 15  0.996461
# 16  0.220190
# 17  0.229604

# %%
import sys

import os
import pathlib

sys.path.append("../../..")
from training.results import plot_summary, plot_one_type_split

# %% [markdown]
# ## MAE

# %% [markdown]
# ### All types of splits

# %%
plot_summary(results, "MAE", title="MAE for Random Forest")

# %% [markdown]
# Only tuned models

# %%
plot_summary(
    results[results["Tuning type"] != "default"],
    "MAE",
    title="MAE for tuned Random Forest",
)

# %% [markdown]
# ### Random split

# %%
plot_one_type_split(
    results, "random", "MAE", title="MAE for Random Forest with random split"
)

# %% [markdown]
# Only tuned models

# %%
plot_one_type_split(
    results[results["Tuning type"] != "default"],
    "random",
    "MAE",
    title="MAE for tuned Random Forest with random split",
)

# %% [markdown]
# ### Chronological split

# %%
plot_one_type_split(
    results,
    "chronological",
    "MAE",
    title="MAE for Random Forest with chronological split",
)

# %% [markdown]
# Only tuned models

# %%
plot_one_type_split(
    results[results["Tuning type"] != "default"],
    "chronological",
    "MAE",
    title="MAE for tuned Random Forest with chronological split",
)

# %% [markdown]
# ## RMSE

# %% [markdown]
# ### All tyes of splits

# %%
plot_summary(results, "RMSE", title="RMSE for Random Forest")

# %% [markdown]
# Only tuned models

# %%
plot_summary(
    results[results["Tuning type"] != "default"],
    "RMSE",
    title="RMSE for tuned Random Forest",
)

# %% [markdown]
# ### Random split

# %%
plot_one_type_split(
    results, "random", "RMSE", title="RMSE for Random Forest with random split"
)

# %% [markdown]
# Only tuned models

# %%
plot_one_type_split(
    results[results["Tuning type"] != "default"],
    "random",
    "RMSE",
    title="RMSE for tuned Random Forest with random split",
)

# %% [markdown]
# ### Chronological split

# %%
plot_one_type_split(
    results,
    "chronological",
    "RMSE",
    title="RMSE for Random Forest with chronological split",
)

# %% [markdown]
# Only tuned models

# %%
plot_one_type_split(
    results[results["Tuning type"] != "default"],
    "chronological",
    "RMSE",
    title="RMSE for tuned Random Forest with chronological split",
)
